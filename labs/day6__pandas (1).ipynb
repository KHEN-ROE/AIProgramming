# %% [markdown]
# # Lab12 - Pandas

# %% [markdown]
# ## 0. Prerequisite

# %%
# !pip install mypy
from IPython.core.magic import register_cell_magic
from IPython import get_ipython
from mypy import api

@register_cell_magic
def mypy(line, cell):
  for output in api.run(['-c', '\n' + cell] + line.split()):
    if output and not output.startswith('Success'):
      raise TypeError(output)
  get_ipython().run_cell(cell)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting mypy
#   Downloading mypy-1.2.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 46.2 MB/s eta 0:00:00
# Collecting mypy-extensions>=1.0.0
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Requirement already satisfied: tomli>=1.1.0 in /usr/local/lib/python3.9/dist-packages (from mypy) (2.0.1)
# Requirement already satisfied: typing-extensions>=3.10 in /usr/local/lib/python3.9/dist-packages (from mypy) (4.5.0)
# Installing collected packages: mypy-extensions, mypy
# Successfully installed mypy-1.2.0 mypy-extensions-1.0.0

# %%
from google.colab import drive

drive.mount('/content/gdrive/', force_remount=True)
# Out:
# Mounted at /content/gdrive/

# %%
# !cat /content/gdrive/MyDrive/UN.txt

# %% [markdown]
# ## 1. Data Import

# %%
import pandas as pd

# https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html
fileName = '/content/gdrive/MyDrive/UN.txt'
df = pd.read_csv(fileName, header=None, names=['Country', 'Continent', 'Population', 'Area']) #헤더가 없어서 헤더를 설정해줌
df.head()
# Out:
#        Country Continent  Population      Area
# 0  Afghanistan      Asia      31.800  251772.0
# 1      Albania    Europe       3.000   11100.0
# 2      Algeria    Africa      38.300  919595.0
# 3      Andorra    Europe       0.085     181.0
# 4       Angola    Africa      19.100  481354.0

# %%
df = pd.read_csv('https://raw.githubusercontent.com/agconti/kaggle-titanic/master/data/train.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
lst = pd.read_html('https://docs.python.org/3/library/operator.html')
for df in lst:
  print(df.head())

df = lst[0]  
df.head()
# Out:
#           Operation       Syntax            Function
# 0          Addition        a + b           add(a, b)
# 1     Concatenation  seq1 + seq2  concat(seq1, seq2)
# 2  Containment Test   obj in seq  contains(seq, obj)
# 3          Division        a / b       truediv(a, b)
# 4          Division       a // b      floordiv(a, b)
#           Operation       Syntax            Function
# 0          Addition        a + b           add(a, b)
# 1     Concatenation  seq1 + seq2  concat(seq1, seq2)
# 2  Containment Test   obj in seq  contains(seq, obj)
# 3          Division        a / b       truediv(a, b)
# 4          Division       a // b      floordiv(a, b)

# %%
# !pip install SQLAlchemy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: SQLAlchemy in /usr/local/lib/python3.9/dist-packages (2.0.9)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.9/dist-packages (from SQLAlchemy) (4.5.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.9/dist-packages (from SQLAlchemy) (2.0.2)

# %%
import sqlalchemy

url = ' jdbc:mysql://localhost:3306/musthave'
engine = sqlalchemy.create_engine(url)

from sqlalchemy.sql import text
sql = '''
    SELECT * FROM titanic;
'''
with engine.connect() as conn:
    query = conn.execute(text(sql))         
df = pd.DataFrame(query.fetchall())
df

# %% [markdown]
# ## 2. Data Export

# %%
lst = pd.read_html('https://docs.python.org/3/library/operator.html')
df = lst[0]
df.to_csv('/content/gdrive/MyDrive/Python_Operator.csv')

# %%
# !cat /content/gdrive/MyDrive/Python_Operator.csv
# Out:
# ,Operation,Syntax,Function
# 0,Addition,a + b,"add(a, b)"
# 1,Concatenation,seq1 + seq2,"concat(seq1, seq2)"
# 2,Containment Test,obj in seq,"contains(seq, obj)"
# 3,Division,a / b,"truediv(a, b)"
# 4,Division,a // b,"floordiv(a, b)"
# 5,Bitwise And,a & b,"and_(a, b)"
# 6,Bitwise Exclusive Or,a ^ b,"xor(a, b)"
# 7,Bitwise Inversion,~ a,invert(a)
# 8,Bitwise Or,a | b,"or_(a, b)"
# 9,Exponentiation,a ** b,"pow(a, b)"
# 10,Identity,a is b,"is_(a, b)"
# 11,Identity,a is not b,"is_not(a, b)"
# 12,Indexed Assignment,obj[k] = v,"setitem(obj, k, v)"
# 13,Indexed Deletion,del obj[k],"delitem(obj, k)"
# 14,Indexing,obj[k],"getitem(obj, k)"
# 15,Left Shift,a << b,"lshift(a, b)"
# 16,Modulo,a % b,"mod(a, b)"
# 17,Multiplication,a * b,"mul(a, b)"
# 18,Matrix Multiplication,a @ b,"matmul(a, b)"
# 19,Negation (Arithmetic),- a,neg(a)
# 20,Negation (Logical),not a,not_(a)
# 21,Positive,+ a,pos(a)
# 22,Right Shift,a >> b,"rshift(a, b)"
# 23,Slice Assignment,seq[i:j] = values,"setitem(seq, slice(i, j), values)"
# 24,Slice Deletion,del seq[i:j],"delitem(seq, slice(i, j))"
# 25,Slicing,seq[i:j],"getitem(seq, slice(i, j))"
# 26,String Formatting,s % obj,"mod(s, obj)"
# 27,Subtraction,a - b,"sub(a, b)"
# 28,Truth Test,obj,truth(obj)
# 29,Ordering,a < b,"lt(a, b)"
# 30,Ordering,a <= b,"le(a, b)"
# 31,Equality,a == b,"eq(a, b)"
# 32,Difference,a != b,"ne(a, b)"
# 33,Ordering,a >= b,"ge(a, b)"
# 34,Ordering,a > b,"gt(a, b)"

# %%
df = pd.read_csv('https://raw.githubusercontent.com/agconti/kaggle-titanic/master/data/train.csv')
df.head().to_markdown('/content/gdrive/MyDrive/titanic_train.md')

# %%
# !cat /content/gdrive/MyDrive/titanic_train.md
# Out:
# |    |   PassengerId |   Survived |   Pclass | Name                                                | Sex    |   Age |   SibSp |   Parch | Ticket           |    Fare | Cabin   | Embarked   |
# |---:|--------------:|-----------:|---------:|:----------------------------------------------------|:-------|------:|--------:|--------:|:-----------------|--------:|:--------|:-----------|
# |  0 |             1 |          0 |        3 | Braund, Mr. Owen Harris                             | male   |    22 |       1 |       0 | A/5 21171        |  7.25   | nan     | S          |
# |  1 |             2 |          1 |        1 | Cumings, Mrs. John Bradley (Florence Briggs Thayer) | female |    38 |       1 |       0 | PC 17599         | 71.2833 | C85     | C          |
# |  2 |             3 |          1 |        3 | Heikkinen, Miss. Laina                              | female |    26 |       0 |       0 | STON/O2. 3101282 |  7.925  | nan     | S          |
# |  3 |             4 |          1 |        1 | Futrelle, Mrs. Jacques Heath (Lily May Peel)        | female |    35 |       1 |       0 | 113803           | 53.1    | C123    | S          |
# |  4 |             5 |          0 |        3 | Allen, Mr. William Henry                            | male   |    35 |       0 |       0 | 373450           |  8.05   | nan     | S          |

# %% [markdown]
# ## 3. DataFrame Operators

# %%
# https://www.kaggle.com/competitions/titanic/data

df = pd.read_csv('https://raw.githubusercontent.com/agconti/kaggle-titanic/master/data/train.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df['Pclass'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.mode.html

df['Pclass'].mode()
# Out:
# 0    3
# Name: Pclass, dtype: int64

# %%
df.nlargest(3, ['Age'])
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 851          852         0       3                   Svensson, Mr. Johan
# 96            97         0       1             Goldschmidt, Mr. George B
#
#       Sex   Age  SibSp  Parch    Ticket     Fare Cabin Embarked
# 630  male  80.0      0      0     27042  30.0000   A23        S
# 851  male  74.0      0      0    347060   7.7750   NaN        S
# 96   male  71.0      0      0  PC 17754  34.6542    A5        C

# %%
lower = df.Age.quantile(0.05)
upper = df.Age.quantile(0.95)
#df.clip(lower=lower, upper=upper) # the age cloumn includes missing values
print(lower,upper)
# Out:
# 4.0 56.0

# %%
df.sum(numeric_only=True)
# Out:
# PassengerId    397386.0000
# Survived          342.0000
# Pclass           2057.0000
# Age             21205.1700
# SibSp             466.0000
# Parch             340.0000
# Fare            28693.9493
# dtype: float64

# %%
df.sum(numeric_only=True, axis=1)
# Out:
# 0       34.2500
# 1      114.2833
# 2       40.9250
# 3       95.1000
# 4       51.0500
#          ...
# 886    929.0000
# 887    939.0000
# 888    918.4500
# 889    948.0000
# 890    933.7500
# Length: 891, dtype: float64

# %% [markdown]
# ## 4. Creating DataFrames from/to list, dict, and numpy

# %%
lst = [ 1, 2, 3 ]
df = pd.DataFrame(lst, columns=['num'])
df
# Out:
#    num
# 0    1
# 1    2
# 2    3

# %%
d = dict = {'a': [1, 2, 3],
        'b': [4, 5, 6]}
df = pd.DataFrame(d) # 키가 컬럼명이 됨
df
# Out:
#    a  b
# 0  1  4
# 1  2  5
# 2  3  6

# %%
import numpy as np
arr = np.array([[1, 2, 3],
         [4, 5, 6]])
df = pd.DataFrame(arr, columns=['num1', 'num2', 'num3'])
df
# Out:
#    num1  num2  num3
# 0     1     2     3
# 1     4     5     6

# %%
df = pd.read_csv('https://raw.githubusercontent.com/agconti/kaggle-titanic/master/data/train.csv')
df.to_dict('list')

# %%
df.values
# Out:
# array([[1, 0, 3, ..., 7.25, nan, 'S'],
#        [2, 1, 1, ..., 71.2833, 'C85', 'C'],
#        [3, 1, 3, ..., 7.925, nan, 'S'],
#        ...,
#        [889, 0, 3, ..., 23.45, nan, 'S'],
#        [890, 1, 1, ..., 30.0, 'C148', 'C'],
#        [891, 0, 3, ..., 7.75, nan, 'Q']], dtype=object)

# %%
df.values.tolist()

# %% [markdown]
#  ## 5. Inserting and Deleting Rows and Columns

# %%
df = pd.read_csv('https://raw.githubusercontent.com/agconti/kaggle-titanic/master/data/train.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
first = lambda x: x[0]
second = lambda x: x[1]

def getFirstName(df):
  return df.Name.str.replace(',','').str.split().apply(first)
#def getSeconName(df):
#  return df.Name.str.replace(',','').str.split().apply(second)

df2 = df.copy() #안전하게 복사본 만듦
df2['FirstName'] = getFirstName(df)
#df2['SecondName'] = getSecondName(df)
df2.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  FirstName
# 0      0         A/5 21171   7.2500   NaN        S     Braund
# 1      0          PC 17599  71.2833   C85        C    Cumings
# 2      0  STON/O2. 3101282   7.9250   NaN        S  Heikkinen
# 3      0            113803  53.1000  C123        S   Futrelle
# 4      0            373450   8.0500   NaN        S      Allen

# %%
df3 = df.copy()
df3.insert(3, 'FirstName', getFirstName(df))
df3.head()
# Out:
#    PassengerId  Survived  Pclass  FirstName  \
# 0            1         0       3     Braund
# 1            2         1       1    Cumings
# 2            3         1       3  Heikkinen
# 3            4         1       1   Futrelle
# 4            5         0       3      Allen
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
dropped_df = df3.drop(['FirstName'], axis=1)
dropped_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ## 6. Indexing and Selecting Data

# %%
df['Name']
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
df[['Name', 'Pclass']]
# Out:
#                                                   Name  Pclass
# 0                              Braund, Mr. Owen Harris       3
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...       1
# 2                               Heikkinen, Miss. Laina       3
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)       1
# 4                             Allen, Mr. William Henry       3
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas       2
# 887                       Graham, Miss. Margaret Edith       1
# 888           Johnston, Miss. Catherine Helen "Carrie"       3
# 889                              Behr, Mr. Karl Howell       1
# 890                                Dooley, Mr. Patrick       3
#
# [891 rows x 2 columns]

# %%
df.iloc[0:0, :]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df.iloc[:, 3:4]
# Out:
#                                                   Name
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# ..                                                 ...
# 886                              Montvila, Rev. Juozas
# 887                       Graham, Miss. Margaret Edith
# 888           Johnston, Miss. Catherine Helen "Carrie"
# 889                              Behr, Mr. Karl Howell
# 890                                Dooley, Mr. Patrick
#
# [891 rows x 1 columns]

# %%
df.iloc[:10, 3:7]
# Out:
#                                                 Name     Sex   Age  SibSp
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1

# %%
df.loc[0:10, 'Name':'SibSp']
# Out:
#                                                  Name     Sex   Age  SibSp
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                            Allen, Mr. William Henry    male  35.0      0
# 5                                    Moran, Mr. James    male   NaN      0
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 7                      Palsson, Master. Gosta Leonard    male   2.0      3
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                 Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1

# %%
df.loc['Total'] = df.sum(numeric_only=True)
df
# Out:
#        PassengerId  Survived  Pclass  \
# 0                1         0       3
# 1                2         1       1
# 2                3         1       3
# 3                4         1       1
# 4                5         0       3
# ...            ...       ...     ...
# 887            888         1       1
# 888            889         0       3
# 889            890         1       1
# 890            891         0       3
# Total      1192158      1026    6171
#
#                                                     Name     Sex       Age  \
# 0                                Braund, Mr. Owen Harris    male     22.00
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...  female     38.00
# 2                                 Heikkinen, Miss. Laina  female     26.00
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)  female     35.00
# 4                               Allen, Mr. William Henry    male     35.00
# ...                                                  ...     ...       ...
# 887                         Graham, Miss. Margaret Edith  female     19.00
# 888             Johnston, Miss. Catherine Helen "Carrie"  female       NaN
# 889                                Behr, Mr. Karl Howell    male     26.00
# 890                                  Dooley, Mr. Patrick    male     32.00
# Total                                                NaN     NaN  63615.51
#
#        SibSp  Parch            Ticket        Fare Cabin Embarked
# 0          1      0         A/5 21171      7.2500   NaN        S
# 1          1      0          PC 17599     71.2833   C85        C
# 2          0      0  STON/O2. 3101282      7.9250   NaN        S
# 3          1      0            113803     53.1000  C123        S
# 4          0      0            373450      8.0500   NaN        S
# ...      ...    ...               ...         ...   ...      ...
# 887        0      0            112053     30.0000   B42        S
# 888        1      2        W./C. 6607     23.4500   NaN        S
# 889        0      0            111369     30.0000  C148        C
# 890        0      0            370376      7.7500   NaN        Q
# Total   1398   1020               NaN  86081.8479   NaN      NaN
#
# [892 rows x 12 columns]

# %%
mask = df['Age']> 25
df[mask]
# Out:
#        PassengerId  Survived  Pclass  \
# 1                2         1       1
# 2                3         1       3
# 3                4         1       1
# 4                5         0       3
# 6                7         0       1
# ...            ...       ...     ...
# 885            886         0       3
# 886            887         0       2
# 889            890         1       1
# 890            891         0       3
# Total      1192158      1026    6171
#
#                                                     Name     Sex       Age  \
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...  female     38.00
# 2                                 Heikkinen, Miss. Laina  female     26.00
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)  female     35.00
# 4                               Allen, Mr. William Henry    male     35.00
# 6                                McCarthy, Mr. Timothy J    male     54.00
# ...                                                  ...     ...       ...
# 885                 Rice, Mrs. William (Margaret Norton)  female     39.00
# 886                                Montvila, Rev. Juozas    male     27.00
# 889                                Behr, Mr. Karl Howell    male     26.00
# 890                                  Dooley, Mr. Patrick    male     32.00
# Total                                                NaN     NaN  63615.51
#
#        SibSp  Parch            Ticket        Fare Cabin Embarked
# 1          1      0          PC 17599     71.2833   C85        C
# 2          0      0  STON/O2. 3101282      7.9250   NaN        S
# 3          1      0            113803     53.1000  C123        S
# 4          0      0            373450      8.0500   NaN        S
# 6          0      0             17463     51.8625   E46        S
# ...      ...    ...               ...         ...   ...      ...
# 885        0      5            382652     29.1250   NaN        Q
# 886        0      0            211536     13.0000   NaN        S
# 889        0      0            111369     30.0000  C148        C
# 890        0      0            370376      7.7500   NaN        Q
# Total   1398   1020               NaN  86081.8479   NaN      NaN
#
# [414 rows x 12 columns]

# %%
(df['Age']> 25) & (df['Name'].str.contains('Mrs.'))
# Out:
# 0      False
# 1       True
# 2      False
# 3       True
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Length: 891, dtype: bool

# %%
# & : element-wise logical and operator
mask = (df['Age']> 25) & (df['Name'].str.contains('Mrs.'))
df[mask]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 8              9         1       3
# 15            16         1       2
# 18            19         0       3
# ..           ...       ...     ...
# 865          866         1       2
# 871          872         1       1
# 874          875         1       2
# 879          880         1       1
# 885          886         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# 18   Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.0      1
# ..                                                 ...     ...   ...    ...
# 865                           Bystrom, Mrs. (Karolina)  female  42.0      0
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0      1
# 874              Abelson, Mrs. Samuel (Hannah Wizosky)  female  28.0      1
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
# 885               Rice, Mrs. William (Margaret Norton)  female  39.0      0
#
#      Parch     Ticket     Fare Cabin Embarked
# 1        0   PC 17599  71.2833   C85        C
# 3        0     113803  53.1000  C123        S
# 8        2     347742  11.1333   NaN        S
# 15       0     248706  16.0000   NaN        S
# 18       0     345763  18.0000   NaN        S
# ..     ...        ...      ...   ...      ...
# 865      0     236852  13.0000   NaN        S
# 871      1      11751  52.5542   D35        S
# 874      0  P/PP 3381  24.0000   NaN        C
# 879      1      11767  83.1583   C50        C
# 885      5     382652  29.1250   NaN        Q
#
# [87 rows x 12 columns]

# %%
df.query("Age > 25 and Name.str.contains('Mrs')")
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 8              9         1       3
# 15            16         1       2
# 18            19         0       3
# ..           ...       ...     ...
# 865          866         1       2
# 871          872         1       1
# 874          875         1       2
# 879          880         1       1
# 885          886         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# 18   Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.0      1
# ..                                                 ...     ...   ...    ...
# 865                           Bystrom, Mrs. (Karolina)  female  42.0      0
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0      1
# 874              Abelson, Mrs. Samuel (Hannah Wizosky)  female  28.0      1
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
# 885               Rice, Mrs. William (Margaret Norton)  female  39.0      0
#
#      Parch     Ticket     Fare Cabin Embarked
# 1        0   PC 17599  71.2833   C85        C
# 3        0     113803  53.1000  C123        S
# 8        2     347742  11.1333   NaN        S
# 15       0     248706  16.0000   NaN        S
# 18       0     345763  18.0000   NaN        S
# ..     ...        ...      ...   ...      ...
# 865      0     236852  13.0000   NaN        S
# 871      1      11751  52.5542   D35        S
# 874      0  P/PP 3381  24.0000   NaN        C
# 879      1      11767  83.1583   C50        C
# 885      5     382652  29.1250   NaN        Q
#
# [87 rows x 12 columns]

# %% [markdown]
# ## 7. Series Operations

# %%
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/agconti/kaggle-titanic/master/data/train.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
filtered_df = df[df['Age'].isin([26, 27, 28])]
filtered_df.reset_index(inplace=False) #inplace = false 변경된 설정 덮어쓰지 않겠다.
filtered_df
# Out:
#      PassengerId  Survived  Pclass  \
# 2              3         1       3
# 8              9         1       3
# 23            24         1       1
# 34            35         0       1
# 41            42         0       2
# ..           ...       ...     ...
# 870          871         0       3
# 874          875         1       2
# 883          884         0       2
# 886          887         0       2
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 23                        Sloper, Mr. William Thompson    male  28.0      0
# 34                             Meyer, Mr. Edgar Joseph    male  28.0      1
# 41   Turpin, Mrs. William John Robert (Dorothy Ann ...  female  27.0      1
# ..                                                 ...     ...   ...    ...
# 870                                  Balkic, Mr. Cerin    male  26.0      0
# 874              Abelson, Mrs. Samuel (Hannah Wizosky)  female  28.0      1
# 883                      Banfield, Mr. Frederick James    male  28.0      0
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 889                              Behr, Mr. Karl Howell    male  26.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 8        2            347742  11.1333   NaN        S
# 23       0            113788  35.5000    A6        S
# 34       0          PC 17604  82.1708   NaN        C
# 41       0             11668  21.0000   NaN        S
# ..     ...               ...      ...   ...      ...
# 870      0            349248   7.8958   NaN        S
# 874      0         P/PP 3381  24.0000   NaN        C
# 883      0  C.A./SOTON 34068  10.5000   NaN        S
# 886      0            211536  13.0000   NaN        S
# 889      0            111369  30.0000  C148        C
#
# [61 rows x 12 columns]

# %%
df['Name'].str.replace(',','').str.split()
# Out:
# 0                            [Braund, Mr., Owen, Harris]
# 1      [Cumings, Mrs., John, Bradley, (Florence, Brig...
# 2                              [Heikkinen, Miss., Laina]
# 3      [Futrelle, Mrs., Jacques, Heath, (Lily, May, P...
# 4                           [Allen, Mr., William, Henry]
#                              ...
# 886                             [Montvila, Rev., Juozas]
# 887                     [Graham, Miss., Margaret, Edith]
# 888        [Johnston, Miss., Catherine, Helen, "Carrie"]
# 889                            [Behr, Mr., Karl, Howell]
# 890                               [Dooley, Mr., Patrick]
# Name: Name, Length: 891, dtype: object

# %%
df[df['Name'].str.contains('Mrs')]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# 15            16         1       2
# ..           ...       ...     ...
# 871          872         1       1
# 874          875         1       2
# 879          880         1       1
# 880          881         1       2
# 885          886         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# ..                                                 ...     ...   ...    ...
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0      1
# 874              Abelson, Mrs. Samuel (Hannah Wizosky)  female  28.0      1
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
# 880       Shelley, Mrs. William (Imanita Parrish Hall)  female  25.0      0
# 885               Rice, Mrs. William (Margaret Norton)  female  39.0      0
#
#      Parch     Ticket     Fare Cabin Embarked
# 1        0   PC 17599  71.2833   C85        C
# 3        0     113803  53.1000  C123        S
# 8        2     347742  11.1333   NaN        S
# 9        0     237736  30.0708   NaN        C
# 15       0     248706  16.0000   NaN        S
# ..     ...        ...      ...   ...      ...
# 871      1      11751  52.5542   D35        S
# 874      0  P/PP 3381  24.0000   NaN        C
# 879      1      11767  83.1583   C50        C
# 880      1     230433  26.0000   NaN        S
# 885      5     382652  29.1250   NaN        Q
#
# [129 rows x 12 columns]

# %%
df['Pclass'].memory_usage()
# Out:
# 7256

# %%
df['Pclass'].astype('category').cat.codes.memory_usage()
# Out:
# 1019

# %%
lower = df['Age'].quantile(0.05)
upper = df['Age'].quantile(0.95)
print(lower, upper)
# Out:
# 4.0 56.0

# %% [markdown]
# ## 8.  Index Operations
#
#  Index objects are ***immutable*** and cannot be modified directly

# %%
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/agconti/kaggle-titanic/master/data/train.csv')
df.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
df.index.values

# %%
df.reset_index(inplace=False)
# Out:
#      index  PassengerId  Survived  Pclass  \
# 0        0            1         0       3
# 1        1            2         1       1
# 2        2            3         1       3
# 3        3            4         1       1
# 4        4            5         0       3
# ..     ...          ...       ...     ...
# 886    886          887         0       2
# 887    887          888         1       1
# 888    888          889         0       3
# 889    889          890         1       1
# 890    890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 13 columns]

# %%
df.reset_index(drop=True, inplace=False)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %% [markdown]
# ## 9.  Aggregation Functions

# %%
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/agconti/kaggle-titanic/master/data/train.csv')
df.sort_values(['Pclass', 'Name'], ascending=[False, True])
# Out:
#      PassengerId  Survived  Pclass                                    Name  \
# 845          846         0       3                     Abbing, Mr. Anthony
# 746          747         0       3             Abbott, Mr. Rossmore Edward
# 279          280         1       3        Abbott, Mrs. Stanton (Rosa Hunt)
# 365          366         0       3          Adahl, Mr. Mauritz Nils Martin
# 401          402         0       3                         Adams, Mr. John
# ..           ...       ...     ...                                     ...
# 155          156         0       1             Williams, Mr. Charles Duane
# 351          352         0       1  Williams-Lambert, Mr. Fletcher Fellows
# 55            56         1       1                       Woolner, Mr. Hugh
# 555          556         0       1                      Wright, Mr. George
# 325          326         1       1                Young, Miss. Marie Grice
#
#         Sex   Age  SibSp  Parch     Ticket      Fare Cabin Embarked
# 845    male  42.0      0      0  C.A. 5547    7.5500   NaN        S
# 746    male  16.0      1      1  C.A. 2673   20.2500   NaN        S
# 279  female  35.0      1      1  C.A. 2673   20.2500   NaN        S
# 365    male  30.0      0      0     C 7076    7.2500   NaN        S
# 401    male  26.0      0      0     341826    8.0500   NaN        S
# ..      ...   ...    ...    ...        ...       ...   ...      ...
# 155    male  51.0      0      1   PC 17597   61.3792   NaN        C
# 351    male   NaN      0      0     113510   35.0000  C128        S
# 55     male   NaN      0      0      19947   35.5000   C52        S
# 555    male  62.0      0      0     113807   26.5500   NaN        S
# 325  female  36.0      0      0   PC 17760  135.6333   C32        C
#
# [891 rows x 12 columns]

# %%
# Count non-NA/null values 
df.count()
# Out:
# PassengerId    891
# Survived       891
# Pclass         891
# Name           891
# Sex            891
# Age            714
# SibSp          891
# Parch          891
# Ticket         891
# Fare           891
# Cabin          204
# Embarked       889
# dtype: int64

# %%
df[['Age', 'Fare']].mean()
# Out:
# Age     29.699118
# Fare    32.204208
# dtype: float64

# %%
grouped_df = df.groupby('Pclass')
grouped_df.count()
# Out:
#         PassengerId  Survived  Name  Sex  Age  SibSp  Parch  Ticket  Fare  \
# Pclass
# 1               216       216   216  216  186    216    216     216   216
# 2               184       184   184  184  173    184    184     184   184
# 3               491       491   491  491  355    491    491     491   491
#
#         Cabin  Embarked
# Pclass
# 1         176       214
# 2          16       184
# 3          12       491

# %%
grouped_df.sum()
# Out:
# <ipython-input-43-6dcb3177b4d1>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   grouped_df.sum()
#         PassengerId  Survived      Age  SibSp  Parch        Fare
# Pclass
# 1             99705       136  7111.42     90     77  18177.4125
# 2             82056        87  5168.83     74     70   3801.8417
# 3            215625       119  8924.92    302    193   6714.6951

# %%
grouped_df[['Age', 'Fare']].mean()
# Out:
#               Age       Fare
# Pclass
# 1       38.233441  84.154687
# 2       29.877630  20.662183
# 3       25.140620  13.675550

# %%
grouped_df.agg({'Fare': 'sum', 'Age': 'mean'})
# Out:
#               Fare        Age
# Pclass
# 1       18177.4125  38.233441
# 2        3801.8417  29.877630
# 3        6714.6951  25.140620

# %%
grouped_df.sample(n=2)
# Out:
#      PassengerId  Survived  Pclass  \
# 766          767         0       1
# 879          880         1       1
# 361          362         0       2
# 801          802         1       2
# 479          480         1       3
# 46            47         0       3
#
#                                               Name     Sex   Age  SibSp  \
# 766                      Brewe, Dr. Arthur Jackson    male   NaN      0
# 879  Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
# 361                      del Carlo, Mr. Sebastiano    male  29.0      1
# 801    Collyer, Mrs. Harvey (Charlotte Annie Tate)  female  31.0      1
# 479                       Hirvonen, Miss. Hildur E  female   2.0      0
# 46                               Lennon, Mr. Denis    male   NaN      1
#
#      Parch         Ticket     Fare Cabin Embarked
# 766      0         112379  39.6000   NaN        C
# 879      1          11767  83.1583   C50        C
# 361      0  SC/PARIS 2167  27.7208   NaN        C
# 801      1     C.A. 31921  26.2500   NaN        S
# 479      1        3101298  12.2875   NaN        S
# 46       0         370371  15.5000   NaN        Q

# %% [markdown]
# ##  10. Missing Data

# %%
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/agconti/kaggle-titanic/master/data/train.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.isna()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# 0    False   True     False
# 1    False  False     False
# 2    False   True     False
# 3    False  False     False
# 4    False   True     False
# ..     ...    ...       ...
# 886  False   True     False
# 887  False  False     False
# 888  False   True     False
# 889  False  False     False
# 890  False   True     False
#
# [891 rows x 12 columns]

# %%
df[df.isna().any(axis=1)]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 2              3         1       3                    Heikkinen, Miss. Laina
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0      male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 2    female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 4      male  35.0      0      0            373450   8.0500   NaN        S
# 5      male   NaN      0      0            330877   8.4583   NaN        Q
# 7      male   2.0      3      1            349909  21.0750   NaN        S
# ..      ...   ...    ...    ...               ...      ...   ...      ...
# 884    male  25.0      0      0   SOTON/OQ 392076   7.0500   NaN        S
# 885  female  39.0      0      5            382652  29.1250   NaN        Q
# 886    male  27.0      0      0            211536  13.0000   NaN        S
# 888  female   NaN      1      2        W./C. 6607  23.4500   NaN        S
# 890    male  32.0      0      0            370376   7.7500   NaN        Q
#
# [708 rows x 12 columns]

# %%
# ffill: propagate last valid observation forward to next valid.
# backfill / bfill: use next valid observation to fill gap.

df_clean = df.fillna(method='ffill')
df_clean = df_clean.fillna(method='backfill')
na_mask = df_clean[df_clean.isna().any(axis=1)]
df_clean[na_mask]
# Out:
#      PassengerId  Survived  Pclass Name  Sex  Age  SibSp  Parch Ticket  Fare  \
# 0            NaN       NaN     NaN  NaN  NaN  NaN    NaN    NaN    NaN   NaN
# 1            NaN       NaN     NaN  NaN  NaN  NaN    NaN    NaN    NaN   NaN
# 2            NaN       NaN     NaN  NaN  NaN  NaN    NaN    NaN    NaN   NaN
# 3            NaN       NaN     NaN  NaN  NaN  NaN    NaN    NaN    NaN   NaN
# 4            NaN       NaN     NaN  NaN  NaN  NaN    NaN    NaN    NaN   NaN
# ..           ...       ...     ...  ...  ...  ...    ...    ...    ...   ...
# 886          NaN       NaN     NaN  NaN  NaN  NaN    NaN    NaN    NaN   NaN
# 887          NaN       NaN     NaN  NaN  NaN  NaN    NaN    NaN    NaN   NaN
# 888          NaN       NaN     NaN  NaN  NaN  NaN    NaN    NaN    NaN   NaN
# 889          NaN       NaN     NaN  NaN  NaN  NaN    NaN    NaN    NaN   NaN
# 890          NaN       NaN     NaN  NaN  NaN  NaN    NaN    NaN    NaN   NaN
#
#     Cabin Embarked
# 0     NaN      NaN
# 1     NaN      NaN
# 2     NaN      NaN
# 3     NaN      NaN
# 4     NaN      NaN
# ..    ...      ...
# 886   NaN      NaN
# 887   NaN      NaN
# 888   NaN      NaN
# 889   NaN      NaN
# 890   NaN      NaN
#
# [891 rows x 12 columns]

# %%
df_clean = df['Age'].fillna(df['Age'].mean())
df_clean.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 891 entries, 0 to 890
# Series name: Age
# Non-Null Count  Dtype
# --------------  -----
# 891 non-null    float64
# dtypes: float64(1)
# memory usage: 7.1 KB

# %%
df_clean.mean()
# Out:
# 29.69911764705882

# %%
df_clean2 = df.fillna(df.mean())
df_clean2.mean()
# Out:
# <ipython-input-73-c62473512cf5>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_clean2 = df.fillna(df.mean())
# <ipython-input-73-c62473512cf5>:2: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_clean2.mean()
# PassengerId    446.000000
# Survived         0.383838
# Pclass           2.308642
# Age             29.699118
# SibSp            0.523008
# Parch            0.381594
# Fare            32.204208
# dtype: float64

# %% [markdown]
# # Lab13

# %%
# !cat /content/gdrive/MyDrive/UN.txt

# %% [markdown]
# * Create a DataFrame from a CSV file (UN.txt).
# * The UN.txt file contains columns: 'Country', 'Continent', 'Population', and 'Area'.

# %%
file = '/content/gdrive/MyDrive/UN.txt'
df = pd.read_csv(file, header=None, names=['Country', 'Continent', 'Population', 'Area'])
df.head()
# Out:
#        Country Continent  Population      Area
# 0  Afghanistan      Asia      31.800  251772.0
# 1      Albania    Europe       3.000   11100.0
# 2      Algeria    Africa      38.300  919595.0
# 3      Andorra    Europe       0.085     181.0
# 4       Angola    Africa      19.100  481354.0

# %% [markdown]
# * Given a DataFrame, filter rows in a DataFrame based on a specific area
# * Sort the output by area size in descending order

# %%
filtered_df = df.sort_values(by='Area', axis=0, ascending=False)
print(filtered_df)
# Out:
#                 Country          Continent  Population        Area
# 140  Russian Federation             Europe    142.5000  6592800.00
# 30               Canada      North America     34.8000  3855000.00
# 184       United States      North America    318.9000  3794066.00
# 35                China               Asia   1355.7000  3696100.00
# 23               Brazil      South America    202.7000  3287597.00
# ..                  ...                ...         ...         ...
# 156     Solomon Islands  Australia/Oceania      0.6100       43.00
# 146          San Marino             Europe      0.0330       23.50
# 178              Tuvalu  Australia/Oceania      0.0110       10.00
# 117               Nauru  Australia/Oceania      0.0095        8.00
# 110              Monaco             Europe      0.0310        0.76
#
# [193 rows x 4 columns]

# %% [markdown]
# * Calculate the average population and area of UN member states.

# %%
pMean = df['Population'].mean()
aMean = df['Area'].mean()
print(pMean)
print(aMean)
# Out:
# 36.972002590673576
# 268550.9557512953

# %% [markdown]
# * Group the DataFrame by 'Continent' and calculate the average population and area for each continent.

# %%
grouped_df = df.groupby('Continent')
gMean = grouped_df.mean()
gMean
# Out:
# <ipython-input-93-6487467130a0>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   gMean = grouped_df.mean()
#                    Population           Area
# Continent
# Africa              20.817074  219275.240741
# Asia                90.862553  261842.302128
# Australia/Oceania    2.565179  233168.000000
# Europe              17.315721  206693.215349
# North America       24.140696  378141.347826
# South America       33.767500  569456.000000

# %% [markdown]
# * Find the top N countries with the highest one from the given DataFrame.

# %%
aFiltered = df.sort_values(by='Area', axis=0, ascending=False)
print(aFiltered)
# Out:
#                 Country          Continent  Population        Area
# 140  Russian Federation             Europe    142.5000  6592800.00
# 30               Canada      North America     34.8000  3855000.00
# 184       United States      North America    318.9000  3794066.00
# 35                China               Asia   1355.7000  3696100.00
# 23               Brazil      South America    202.7000  3287597.00
# ..                  ...                ...         ...         ...
# 156     Solomon Islands  Australia/Oceania      0.6100       43.00
# 146          San Marino             Europe      0.0330       23.50
# 178              Tuvalu  Australia/Oceania      0.0110       10.00
# 117               Nauru  Australia/Oceania      0.0095        8.00
# 110              Monaco             Europe      0.0310        0.76
#
# [193 rows x 4 columns]

# %%
pFiltered = df.sort_values(by="Population", axis=0, ascending=False)
print(pFiltered)
# Out:
#            Country          Continent  Population        Area
# 35           China               Asia   1355.7000  3696100.00
# 75           India               Asia   1236.3000  1269210.00
# 184  United States      North America    318.9000  3794066.00
# 76       Indonesia               Asia    253.6000   735355.00
# 23          Brazil      South America    202.7000  3287597.00
# ..             ...                ...         ...         ...
# 146     San Marino             Europe      0.0330       23.50
# 110         Monaco             Europe      0.0310        0.76
# 127          Palau  Australia/Oceania      0.0210      177.00
# 178         Tuvalu  Australia/Oceania      0.0110       10.00
# 117          Nauru  Australia/Oceania      0.0095        8.00
#
# [193 rows x 4 columns]

# %% [markdown]
# * Merge two DataFrames on a common column 'Name'

# %%
# !cat /content/gdrive/MyDrive/employee.csv

# %%
# !cat /content/gdrive/MyDrive/dept.csv

# %%
df1 = pd.read_csv('/content/gdrive/MyDrive/employee.csv')
df2 = pd.read_csv('/content/gdrive/MyDrive/dept.csv')

merged_df = pd.merge(df1,df2, how='outer',on='Name')
merged_df
# Out:
#     Name  Age  Salary  ID Department
# 0  Alice   30   50000   1         HR
# 1    Bob   25   55000   2    Finance
# 2  Carol   35   60000   3         IT
# 3  David   22   45000   4         HR
# 4    Eva   28   65000   5    Finance
# 5  Frank   32   52000   6         IT
# 6  Grace   26   58000   7         HR
# 7  Helen   29   62000   8    Finance
# 8   Ivan   24   48000   9         IT
# 9   Jack   34   70000  10         HR

# %% [markdown]
# * Fill missing values in the given csv  - 'https://raw.githubusercontent.com/agconti/kaggle-titanic/master/data/train.csv'
#
# * Replace missing values in the 'Age' column with the mean age.
# * Replace missing values in the 'Cabin' column with the mode value.
# * Replace missing values in the 'Embarked' column with the mode value.

# %%
missing_df = pd.read_csv('https://raw.githubusercontent.com/agconti/kaggle-titanic/master/data/train.csv') 
#missing_df.info()
df_clean = missing_df['Age'].fillna(missing_df['Age'].mean(), inplace=True)
df_clean = missing_df['Cabin'].fillna(missing_df['Cabin'].mode()[0], inplace=True)
df_clean = missing_df['Embarked'].fillna(missing_df['Embarked'].mode()[0])

df_clean.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 891 entries, 0 to 890
# Series name: Embarked
# Non-Null Count  Dtype
# --------------  -----
# 891 non-null    object
# dtypes: object(1)
# memory usage: 7.1+ KB

# %% [markdown]
# * Calculate the total fare for each passenger in the given DataFrame.

# %%
agg1 = missing_df['Fare'].sum()
agg1
# Out:
# 28693.9493
